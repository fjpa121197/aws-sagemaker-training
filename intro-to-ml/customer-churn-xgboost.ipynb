# %%
import sys
import sagemaker
import boto3
import re
from sagemaker import get_execution_role

# %%
sess = sagemaker.Session()
bucket = sess.default_bucket()
prefix = "sagemaker/aws-sagemaker-training/DEMO-xgboost-churn"

# %%
try:
    # get_execution_role() will only work within Sagemaker studio or notebook instance
    role = sagemaker.get_execution_role()
except ValueError:
    # Will need to get the role ARN by initializing a a new IAM session and get the role by their name
    iam = boto3.client('iam')
    role = iam.get_role(RoleName='AmazonSageMaker-ExecutionRole-20220817T160055')['Role']['Arn']
    print("Role ARN successfully extracted")
# Out:
# Couldn't call 'get_role' to get Role ARN from role name strike-aws-learning to get Role path.
# Role ARN successfully extracted

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
import os
import sys
import time
import json
from IPython.display import display
from time import strftime, gmtime
from sagemaker.inputs import TrainingInput
from sagemaker.serializers import CSVSerializer

# %% [markdown]
# # Data

# %% [markdown]
# ## Download data

# %%
# Initialize S3 client object to download data
s3 = boto3.client("s3")
s3.download_file(f"sagemaker-sample-files", "datasets/tabular/synthetic/churn.txt", "data-samples/churn.txt")

# %%
# Visualize dataset downloaded
churn = pd.read_csv("data-samples/churn.txt")
pd.set_option("display.max_columns", 500)
print(churn.shape)
churn
# Out:
# (5000, 21)
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       PA             163        806  403-2562         no        yes
# 1       SC              15        836  158-8416        yes         no
# 2       MO             131        777  896-6253         no        yes
# 3       WY              75        878  817-5729        yes        yes
# 4       WY             146        878  450-4942        yes         no
# ...    ...             ...        ...       ...        ...        ...
# 4995    NH               4        787  151-3162        yes        yes
# 4996    SD             140        836  351-5993         no         no
# 4997    SC              32        836  370-3127         no        yes
# 4998    MA             142        776  604-2108        yes        yes
# 4999    AL             141        657  294-2849        yes        yes
#
#       VMail Message   Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# 0               300   8.162204          3    7.579174  3.933035          4
# 1                 0  10.018993          4    4.226289  2.325005          0
# 2               300   4.708490          3    4.768160  4.537466          3
# 3               700   1.268734          3    2.567642  2.528748          5
# 4                 0   2.696177          3    5.908916  6.015337          3
# ...             ...        ...        ...         ...       ...        ...
# 4995            800  10.862632          5    7.250969  6.936164          1
# 4996              0   1.581127          8    3.758307  7.377591          7
# 4997            700   0.163836          5    4.243980  5.841852          3
# 4998            600   2.034454          5    3.014859  4.140554          3
# 4999            500   1.803907          0    5.125716  8.357508          0
#
#       Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 0       6.508639    4.065759          100      5.111624   4.928160
# 1       9.972592    7.141040          200      6.436188   3.221748
# 2       4.566715    5.363235          100      5.142451   7.139023
# 3       2.333624    3.773586          450      3.814413   2.245779
# 4       3.670408    3.751673          250      2.796812   6.905545
# ...          ...         ...          ...           ...        ...
# 4995    8.026482    4.921314          350      6.748489   4.872570
# 4996    1.328827    0.939932          300      4.522661   6.938571
# 4997    2.340554    0.939469          450      5.157898   4.388328
# 4998    3.470372    6.076043          150      4.362780   7.173376
# 4999    2.109823    2.624299          400      3.713631   5.798783
#
#       Intl Calls  Intl Charge  CustServ Calls  Churn?
# 0              6     5.673203               3   True.
# 1              6     2.559749               8  False.
# 2              2     6.254157               4  False.
# 3              6     1.080692               6  False.
# 4              4     7.134343               6   True.
# ...          ...          ...             ...     ...
# 4995           8     2.122530               9  False.
# 4996           2     4.600473               4  False.
# 4997           7     1.060340               6  False.
# 4998           3     4.871900               7   True.
# 4999           6     5.485345               7  False.
#
# [5000 rows x 21 columns]

# %% [markdown]
# ## Prepare data for training
#
# Drop columns, encode target variable and split data

# %%
churn = churn.drop("Phone", axis=1)
churn["Area Code"] = churn["Area Code"].astype(object)
churn = churn.drop(["Day Charge", "Eve Charge", "Night Charge", "Intl Charge"], axis=1)

# %%
model_data = pd.get_dummies(churn)
model_data = pd.concat(
    [model_data["Churn?_True."], model_data.drop(["Churn?_False.", "Churn?_True."], axis=1)], axis=1
)
# Out:
# C:\Users\franc\AppData\Local\Temp\ipykernel_25996\3993789765.py:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   model_data = pd.get_dummies(churn)

# %%
train_data, validation_data, test_data = np.split(
    model_data.sample(frac=1, random_state=1729),
    [int(0.7 * len(model_data)), int(0.9 * len(model_data))],
)
train_data.to_csv("data-samples/customer-churn-xgboost-train.csv", header=False, index=False)
validation_data.to_csv("data-samples/customer-churn-xgboost-validation.csv", header=False, index=False)

# %%
# Upload data to S3 bucket to be used in training
# Note: When in windows, there is combination of \ and / done when using os.path.join, which might mess up the folder creation in S3. Using .replace() after os.path.join to change all \
# used in Windows to / and then create correct folders in S3
boto3.Session().resource("s3").Bucket(bucket).Object(os.path.join(prefix, "train/train.csv").replace("\\","/")).upload_file("data-samples/customer-churn-xgboost-train.csv")
boto3.Session().resource("s3").Bucket(bucket).Object(os.path.join(prefix, "validation/validation.csv").replace("\\","/")).upload_file("data-samples/customer-churn-xgboost-validation.csv")

# %% [markdown]
# # Train

# %%
# Get container image name for XGBoost
container = sagemaker.image_uris.retrieve("xgboost", sess.boto_region_name, "1.5-1")
display(container)
# Out:
# '764974769150.dkr.ecr.eu-west-2.amazonaws.com/sagemaker-xgboost:1.5-1'

# %%
# Define training and validation dataset input location
s3_input_train = TrainingInput(s3_data="s3://{}/{}/train".format(bucket, prefix), content_type="csv")
s3_input_validation = TrainingInput(s3_data="s3://{}/{}/validation/".format(bucket, prefix), content_type="csv")

# %%
# Create Estimator object using Sagemaker SDK, which will help us to create a training job (on AWS) easier when calling .fit()
xgb = sagemaker.estimator.Estimator(
    container, # container image name previously obtained
    role,
    instance_count=1,
    instance_type="ml.m4.xlarge", # type of AWS instance to use
    output_path="s3://{}/{}/output".format(bucket, prefix), # location to store final trained model
    sagemaker_session=sess,
)

# Set hyperparameters for XGBoost model
xgb.set_hyperparameters(
    max_depth=5,
    eta=0.2,
    gamma=4,
    min_child_weight=6,
    subsample=0.8,
    verbosity=0,
    objective="binary:logistic",
    num_round=100,
)

# Train estimator, XGBoost model, by calling .fit() and passing the location of the train and validation set
xgb.fit({"train": s3_input_train, "validation": s3_input_validation})
# Out:
# 2022-09-25 11:19:58 Starting - Starting the training job...
# 2022-09-25 11:20:22 Starting - Preparing the instances for trainingProfilerReport-1664104794: InProgress
# ......
# 2022-09-25 11:21:32 Downloading - Downloading input data......
# 2022-09-25 11:22:22 Training - Downloading the training image......
# 2022-09-25 11:23:33 Uploading - Uploading generated training model[2022-09-25 11:23:22.809 ip-10-0-218-31.eu-west-2.compute.internal:1 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-09-25:11:23:22:INFO] Imported framework sagemaker_xgboost_container.training
# [2022-09-25:11:23:22:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2022-09-25:11:23:22:INFO] No GPUs detected (normal if no gpus installed)
# [2022-09-25:11:23:22:INFO] Running XGBoost Sagemaker in algorithm mode
# [2022-09-25:11:23:22:INFO] Determined delimiter of CSV input is ','
# [2022-09-25:11:23:22:INFO] Determined delimiter of CSV input is ','
# [2022-09-25:11:23:22:INFO] files path: /opt/ml/input/data/train
# [2022-09-25:11:23:22:INFO] Determined delimiter of CSV input is ','
# [2022-09-25:11:23:22:INFO] files path: /opt/ml/input/data/validation
# [2022-09-25:11:23:22:INFO] Determined delimiter of CSV input is ','
# [2022-09-25:11:23:22:INFO] Single node training.
# [2022-09-25:11:23:22:INFO] Train matrix has 3500 rows and 99 columns
# [2022-09-25:11:23:22:INFO] Validation matrix has 1000 rows
# [2022-09-25 11:23:22.989 ip-10-0-218-31.eu-west-2.compute.internal:1 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [0]#011train-logloss:0.57858#011validation-logloss:0.58133
# [1]#011train-logloss:0.49925#011validation-logloss:0.50453
# [2]#011train-logloss:0.44009#011validation-logloss:0.44830
# [3]#011train-logloss:0.39167#011validation-logloss:0.40143
# [4]#011train-logloss:0.35545#011validation-logloss:0.36768
# [5]#011train-logloss:0.32624#011validation-logloss:0.34147
# [6]#011train-logloss:0.30245#011validation-logloss:0.31774
# [7]#011train-logloss:0.28221#011validation-logloss:0.29817
# [8]#011train-logloss:0.26325#011validation-logloss:0.28034
# [9]#011train-logloss:0.24988#011validation-logloss:0.26642
# [10]#011train-logloss:0.23750#011validation-logloss:0.25595
# [11]#011train-logloss:0.22734#011validation-logloss:0.24663
# [12]#011train-logloss:0.21684#011validation-logloss:0.23701
# [13]#011train-logloss:0.21068#011validation-logloss:0.23173
# [14]#011train-logloss:0.20671#011validation-logloss:0.22800
# [15]#011train-logloss:0.20342#011validation-logloss:0.22548
# [16]#011train-logloss:0.19905#011validation-logloss:0.22112
# [17]#011train-logloss:0.19404#011validation-logloss:0.21678
# [18]#011train-logloss:0.18728#011validation-logloss:0.21037
# [19]#011train-logloss:0.18454#011validation-logloss:0.20805
# [20]#011train-logloss:0.18055#011validation-logloss:0.20685
# [21]#011train-logloss:0.17796#011validation-logloss:0.20433
# [22]#011train-logloss:0.17636#011validation-logloss:0.20207
# [23]#011train-logloss:0.17514#011validation-logloss:0.20193
# [24]#011train-logloss:0.17261#011validation-logloss:0.20049
# [25]#011train-logloss:0.17097#011validation-logloss:0.20000
# [26]#011train-logloss:0.16957#011validation-logloss:0.19881
# [27]#011train-logloss:0.16593#011validation-logloss:0.19773
# [28]#011train-logloss:0.16476#011validation-logloss:0.19695
# [29]#011train-logloss:0.16414#011validation-logloss:0.19679
# [30]#011train-logloss:0.16298#011validation-logloss:0.19558
# [31]#011train-logloss:0.15978#011validation-logloss:0.19318
# [32]#011train-logloss:0.15725#011validation-logloss:0.19184
# [33]#011train-logloss:0.15603#011validation-logloss:0.19173
# [34]#011train-logloss:0.15304#011validation-logloss:0.19011
# [35]#011train-logloss:0.15193#011validation-logloss:0.18907
# [36]#011train-logloss:0.15030#011validation-logloss:0.18843
# [37]#011train-logloss:0.14935#011validation-logloss:0.18789
# [38]#011train-logloss:0.14876#011validation-logloss:0.18693
# [39]#011train-logloss:0.14769#011validation-logloss:0.18538
# [40]#011train-logloss:0.14369#011validation-logloss:0.18468
# [41]#011train-logloss:0.14235#011validation-logloss:0.18458
# [42]#011train-logloss:0.14235#011validation-logloss:0.18452
# [43]#011train-logloss:0.14154#011validation-logloss:0.18393
# [44]#011train-logloss:0.14037#011validation-logloss:0.18445
# [45]#011train-logloss:0.13839#011validation-logloss:0.18226
# [46]#011train-logloss:0.13773#011validation-logloss:0.18191
# [47]#011train-logloss:0.13635#011validation-logloss:0.18125
# [48]#011train-logloss:0.13542#011validation-logloss:0.18091
# [49]#011train-logloss:0.13404#011validation-logloss:0.18070
# [50]#011train-logloss:0.13351#011validation-logloss:0.18078
# [51]#011train-logloss:0.13249#011validation-logloss:0.18140
# [52]#011train-logloss:0.13249#011validation-logloss:0.18139
# [53]#011train-logloss:0.13177#011validation-logloss:0.18173
# [54]#011train-logloss:0.13177#011validation-logloss:0.18171
# [55]#011train-logloss:0.13001#011validation-logloss:0.18160
# [56]#011train-logloss:0.12822#011validation-logloss:0.18031
# [57]#011train-logloss:0.12822#011validation-logloss:0.18031
# [58]#011train-logloss:0.12719#011validation-logloss:0.17991
# [59]#011train-logloss:0.12719#011validation-logloss:0.17993
# [60]#011train-logloss:0.12719#011validation-logloss:0.17994
# [61]#011train-logloss:0.12719#011validation-logloss:0.17993
# [62]#011train-logloss:0.12719#011validation-logloss:0.17994
# [63]#011train-logloss:0.12631#011validation-logloss:0.18049
# [64]#011train-logloss:0.12631#011validation-logloss:0.18051
# [65]#011train-logloss:0.12540#011validation-logloss:0.18010
# [66]#011train-logloss:0.12440#011validation-logloss:0.17888
# [67]#011train-logloss:0.12331#011validation-logloss:0.17796
# [68]#011train-logloss:0.12294#011validation-logloss:0.17767
# [69]#011train-logloss:0.12148#011validation-logloss:0.17690
# [70]#011train-logloss:0.12120#011validation-logloss:0.17676
# [71]#011train-logloss:0.12120#011validation-logloss:0.17675
# [72]#011train-logloss:0.12120#011validation-logloss:0.17679
# [73]#011train-logloss:0.12053#011validation-logloss:0.17618
# [74]#011train-logloss:0.12053#011validation-logloss:0.17621
# [75]#011train-logloss:0.12052#011validation-logloss:0.17623
# [76]#011train-logloss:0.12052#011validation-logloss:0.17622
# [77]#011train-logloss:0.11979#011validation-logloss:0.17575
# [78]#011train-logloss:0.11979#011validation-logloss:0.17576
# [79]#011train-logloss:0.11934#011validation-logloss:0.17614
# [80]#011train-logloss:0.11860#011validation-logloss:0.17671
# [81]#011train-logloss:0.11806#011validation-logloss:0.17671
# [82]#011train-logloss:0.11806#011validation-logloss:0.17671
# [83]#011train-logloss:0.11755#011validation-logloss:0.17701
# [84]#011train-logloss:0.11755#011validation-logloss:0.17702
# [85]#011train-logloss:0.11543#011validation-logloss:0.17452
# [86]#011train-logloss:0.11543#011validation-logloss:0.17451
# [87]#011train-logloss:0.11514#011validation-logloss:0.17456
# [88]#011train-logloss:0.11463#011validation-logloss:0.17355
# [89]#011train-logloss:0.11463#011validation-logloss:0.17352
# [90]#011train-logloss:0.11463#011validation-logloss:0.17353
# [91]#011train-logloss:0.11463#011validation-logloss:0.17353
# [92]#011train-logloss:0.11427#011validation-logloss:0.17374
# [93]#011train-logloss:0.11397#011validation-logloss:0.17336
# [94]#011train-logloss:0.11397#011validation-logloss:0.17338
# [95]#011train-logloss:0.11397#011validation-logloss:0.17336
# [96]#011train-logloss:0.11397#011validation-logloss:0.17334
# [97]#011train-logloss:0.11397#011validation-logloss:0.17336
# [98]#011train-logloss:0.11397#011validation-logloss:0.17338
# [99]#011train-logloss:0.11397#011validation-logloss:0.17337
#
# 2022-09-25 11:24:02 Completed - Training job completed
# ProfilerReport-1664104794: NoIssuesFound
# Training seconds: 137
# Billable seconds: 137

# %% [markdown]
# A trained model will be store in the bucket and location specified below, for our case, it will be in:
#
# <code>sagemaker/aws-sagemaker-training/DEMO-xgboost-churn/output/sagemaker-xgboost-2022-09-25-11-19-54-022/output/model.tar.gz</code>
#
# It can be used for deploying an endpoint for inference, in real-time, or for batch prediction.
